# %% [markdown]
# # Task 1
# Підготуйте дані для аналізу.
# * Створіть невеликий набір із 5-7 речень (наприклад, відгуки про продукт).
# * Очистіть текст від пунктуації та приведіть до нижнього регістру.
# * Розділіть текст на токени (слова) за допомогою nltk.word_tokenize.
# * Підрахуйте загальну кількість токенів і виведіть перші 10.

# %%
feedbacks = """
1. Great communication throughout the project — updates were always clear and timely.
2. The final result exceeded expectations and was delivered ahead of schedule.
3. Very professional and easy to work with from start to finish.
4. Attention to detail was impressive, especially in the final revisions.
5. Fast response times and excellent problem-solving skills.
6. The work quality was outstanding and matched all requirements perfectly.
7. Reliable, creative, and highly skilled — would definitely collaborate again.
8. Instructions were followed carefully, and the process was smooth overall.
9. Exceptional customer service and strong technical expertise.
10. Delivered exactly what was promised with no unnecessary delays.
11. Very organized workflow and excellent communication at every stage.
12. The project was completed efficiently with high-quality results.
13. Friendly attitude and willingness to make adjustments when needed.
14. One of the best experiences I`ve had working on a project online.
15. Highly recommended for anyone looking for dependable and professional work.
"""

# %%
import re

# %%
def prepare(phrase:str)->str:
   return re.sub('\n', ' ', re.sub(r'([^\w\s])+','', phrase.lower()))

prepared = prepare(feedbacks)
prepared
# Out:
# ' 1 great communication throughout the project  updates were always clear and timely 2 the final result exceeded expectations and was delivered ahead of schedule 3 very professional and easy to work with from start to finish 4 attention to detail was impressive especially in the final revisions 5 fast response times and excellent problemsolving skills 6 the work quality was outstanding and matched all requirements perfectly 7 reliable creative and highly skilled  would definitely collaborate again 8 instructions were followed carefully and the process was smooth overall 9 exceptional customer service and strong technical expertise 10 delivered exactly what was promised with no unnecessary delays 11 very organized workflow and excellent communication at every stage 12 the project was completed efficiently with highquality results 13 friendly attitude and willingness to make adjustments when needed 14 one of the best experiences ive had working on a project online 15 highly recommended for anyone looking for dependable and professional work '

# %%
import nltk
from nltk.tokenize import word_tokenize

# %%
nltk.download(["punkt_tab", "stopwords", "wordnet"])
words = word_tokenize(prepared)
words
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Golo_bs09\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Golo_bs09\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Golo_bs09\AppData\Roaming\nltk_data...
# ['1',
#  'great',
#  'communication',
#  'throughout',
#  'the',
#  'project',
#  'updates',
#  'were',
#  'always',
#  'clear',
#  'and',
#  'timely',
#  '2',
#  'the',
#  'final',
#  'result',
#  'exceeded',
#  'expectations',
#  'and',
#  'was',
#  'delivered',
#  'ahead',
#  'of',
#  'schedule',
#  '3',
#  'very',
#  'professional',
#  'and',
#  'easy',
#  'to',
#  'work',
#  'with',
#  'from',
#  'start',
#  'to',
#  'finish',
#  '4',
#  'attention',
#  'to',
#  'detail',
#  'was',
#  'impressive',
#  'especially',
#  'in',
#  'the',
#  'final',
#  'revisions',
#  '5',
#  'fast',
#  'response',
#  'times',
#  'and',
#  'excellent',
#  'problemsolving',
#  'skills',
#  '6',
#  'the',
#  'work',
#  'quality',
#  'was',
#  'outstanding',
#  'and',
#  'matched',
#  'all',
#  'requirements',
#  'perfectly',
#  '7',
#  'reliable',
#  'creative',
#  'and',
#  'highly',
#  'skilled',
#  'would',
#  'definitely',
#  'collaborate',
#  'again',
#  '8',
#  'instructions',
#  'were',
#  'followed',
#  'carefully',
#  'and',
#  'the',
#  'process',
#  'was',
#  'smooth',
#  'overall',
#  '9',
#  'exceptional',
#  'customer',
#  'service',
#  'and',
#  'strong',
#  'technical',
#  'expertise',
#  '10',
#  'delivered',
#  'exactly',
#  'what',
#  'was',
#  'promised',
#  'with',
#  'no',
#  'unnecessary',
#  'delays',
#  '11',
#  'very',
#  'organized',
#  'workflow',
#  'and',
#  'excellent',
#  'communication',
#  'at',
#  'every',
#  'stage',
#  '12',
#  'the',
#  'project',
#  'was',
#  'completed',
#  'efficiently',
#  'with',
#  'highquality',
#  'results',
#  '13',
#  'friendly',
#  'attitude',
#  'and',
#  'willingness',
#  'to',
#  'make',
#  'adjustments',
#  'when',
#  'needed',
#  '14',
#  'one',
#  'of',
#  'the',
#  'best',
#  'experiences',
#  'ive',
#  'had',
#  'working',
#  'on',
#  'a',
#  'project',
#  'online',
#  '15',
#  'highly',
#  'recommended',
#  'for',
#  'anyone',
#  'looking',
#  'for',
#  'dependable',
#  'and',
#  'professional',
#  'work']

# %% [markdown]
# # Task 2
# Застосуйте лематизацію та стеммінг.
# * Завантажте WordNetLemmatizer і PorterStemmer з бібліотеки NLTK.
# * Перетворіть усі токени на леми і на стеми.
# * Порівняйте перші 10 вихідних слів, їхні леми та стеми в таблиці. Наприклад, так:

# %%
count = -1
for i in words:
    count += 1
    if count < 10:
        print(i)
# Out:
# 1
# great
# communication
# throughout
# the
# project
# updates
# were
# always
# clear

# %%
print(len(words), words[:10])
# Out:
# 158 ['1', 'great', 'communication', 'throughout', 'the', 'project', 'updates', 'were', 'always', 'clear']

# %%
from nltk.stem import WordNetLemmatizer, PorterStemmer

# %%
lemmatizer = WordNetLemmatizer()
lemma = lemmatizer.lemmatize(words[8])
print(lemma)
stemmer = PorterStemmer()
stem = stemmer.stem(words[8])
print(stem)
# Out:
# always
# alway

# %%
from IPython.display import Markdown as md

# %%
count_2 = -1
md("|Begin word|Lemma|Stem|\n|-|-|-|\n" + "\n".join(
        (f"|{w}|{lemmatizer.lemmatize(w)}|{stemmer.stem(w)}|" for w in words[:10])
))
# Out:
# |Begin word|Lemma|Stem|
# |-|-|-|
# |1|1|1|
# |great|great|great|
# |communication|communication|commun|
# |throughout|throughout|throughout|
# |the|the|the|
# |project|project|project|
# |updates|update|updat|
# |were|were|were|
# |always|always|alway|
# |clear|clear|clear|

# %% [markdown]
# # Task 3
# Видаліть стоп-слова і проаналізуйте частотність.
# * Завантажте список англійських стоп-слів nltk.corpus.stopwords.words('english').
# * Видаліть із токенів усі стоп-слова.
# * Підрахуйте частоту слів, що залишилися, за допомогою collections.Counter.
# * Виведіть 10 найчастіших слів та їхню кількість.

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
print(stop_words[:10])
print(stop_words[10::-1])
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an']
# ['and', 'an', 'am', 'all', 'ain', 'against', 'again', 'after', 'above', 'about', 'a']

# %%
sem_words = [w for w in words if not w in stop_words]
print(f"words: {len(words)}, semantic words: {len(sem_words)}")
# Out:
# words: 158, semantic words: 108

# %% [markdown]
# # Task 4
# Робота з корпусами NLTK.
# * Завантажте корпус movie_reviews з NLTK.
# * Виберіть 5 випадкових відгуків і виведіть перші 20 токенів із кожного.
# * Визначте, які слова частіше зустрічаються в позитивних, а які — у негативних відгуках.
# * Збережіть результати аналізу в CSV-файл review_tokens.csv зі стовпчиками:

# %%
from collections import Counter

# %%
freqs = Counter(sem_words)
list_corteg = sorted(list(freqs.items()), key=lambda p: p[1], reverse=True)

# %%
counter_10 = 1 
for i in list_corteg:
    if counter_10 < 11:
        print(f"{counter_10}: {i} ")
    counter_10 += 1
# Out:
# 1: ('project', 3)
# 2: ('work', 3)
# 3: ('communication', 2)
# 4: ('final', 2)
# 5: ('delivered', 2)
# 6: ('professional', 2)
# 7: ('excellent', 2)
# 8: ('highly', 2)
# 9: ('1', 1)
# 10: ('great', 1)

# %%
md("|Word|Frequency|\n|-|-|\n" + "\n".join(
        (f"|{w[0]}|{w[1]}|" for w in list_corteg[:10])
))
# Out:
# |Word|Frequency|
# |-|-|
# |project|3|
# |work|3|
# |communication|2|
# |final|2|
# |delivered|2|
# |professional|2|
# |excellent|2|
# |highly|2|
# |1|1|
# |great|1|
