# %% [markdown]
# # Task 1
# * Створіть масив із 20 цілих чисел у діапазоні від 0 до 50.
# * Виведіть вихідний масив.
# * Запитайте у користувача число (порогове значення).
# * Визначте кількість елементів масиву, що перевищують введене користувачем значення, і виведіть результат.
# * Знайдіть максимальне значення в масиві та позицію його першої появи, виведіть обидва результати.
# * Відсортуйте масив за спаданням і виведіть відсортований масив.

# %%
import numpy as np

# %%
arr = np.random.randint(1, 50, size=20)

# %%
print(arr)
# Out:
# [10 22 49 32 10 27  2 25 30  4 45 20 45 26 15 28 21 25 38 34]

# %%
val = int(input('enter threshold value: '))
# Out:
# enter threshold value:  11

# %%
print(f'Count of elements which bigger than input: {len(arr[arr > val])}')
# Out:
# count of elements which bigger than input: 16

# %%
print(f'Max value: {max(arr)}\nHis first position: {np.where(arr == max(arr))[0]}')
# Out:
# Max value: 49
# His first position: [2]

# %% [markdown]
# ### Sorted array

# %%
print(np.sort(arr)[::-1])
# Out:
# [49 45 45 38 34 32 30 28 27 26 25 25 22 21 20 15 10 10  4  2]
