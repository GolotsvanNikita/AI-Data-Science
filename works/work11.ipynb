# %%
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import numpy as np

class Perceptron(nn.Module) :
    def __init__(self) :
        super(Perceptron, self).__init__()
        self.layer1 = nn.Linear(1,1)
        self.activator = nn.Sigmoid()
 
    def forward(self, x) :
        x = self.layer1(x)
        x = self.activator(x)
        return x
 
loss_f = nn.functional.mse_loss

model2 = Perceptron()
bmi2 = torch.randn(100, 1)
noise2 = 0.1 * torch.randn(100, 1)
risk2 = 0.1 * bmi2 + noise2
fig, ax = plt.subplots(4, 8)
lossees2 = []
optimizer = optim.SGD(model2.parameters(), lr=0.01)
for epoch in range(20) :
    output2 = model2(bmi2)
    loss = loss_f(output2, risk2)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    lossees2.append(loss.item())
lossees2

fig, ax = plt.subplots()
ax.scatter(lossees2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 37
#      33     lossees2.append(loss.item())
#      34 lossees2
#      35
#      36 fig, ax = plt.subplots()
# ---> 37 ax.scatter(lossees2)
#      38 plt.show()
#
# File ~\Desktop\AI-Data-Science\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~\Desktop\AI-Data-Science\Lib\site-packages\matplotlib\__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# TypeError: Axes.scatter() missing 1 required positional argument: 'y'
